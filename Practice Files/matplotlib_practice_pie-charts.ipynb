# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# "Explode" July
plt.subplots(figsize=(8,8))
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.pie(y_axis, explode = explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdf39789190>,
#   <matplotlib.patches.Wedge at 0x7fdf39811e20>,
#   <matplotlib.patches.Wedge at 0x7fdf39811a60>,
#   <matplotlib.patches.Wedge at 0x7fdf39780100>,
#   <matplotlib.patches.Wedge at 0x7fdf397801f0>,
#   <matplotlib.patches.Wedge at 0x7fdf39785280>,
#   <matplotlib.patches.Wedge at 0x7fdf395dca30>,
#   <matplotlib.patches.Wedge at 0x7fdf397705b0>,
#   <matplotlib.patches.Wedge at 0x7fdf396f5df0>,
#   <matplotlib.patches.Wedge at 0x7fdf398c1fd0>,
#   <matplotlib.patches.Wedge at 0x7fdf39848340>,
#   <matplotlib.patches.Wedge at 0x7fdf39821670>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign colors for each month
plt.subplots(figsize=(8,8))
colors = ['slateblue', 'magenta', 'lightblue', 'green', 'yellowgreen', 'greenyellow', 'yellow', 'orange', 'tomato', 'mistyrose']
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.pie(y_axis, 
        explode = explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
explode = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
colors = ['slateblue', 'magenta', 'lightblue', 'green', 'yellowgreen', 'greenyellow', 'yellow', 'orange', 'tomato', 'mistyrose']
ax.pie(y_axis, 
    explode = explode_values, 
    shadow = 'true',
    colors=colors,
    startangle= 80,
    labels=x_axis, 
    counterclock='true',
    autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdf3b60dbe0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b6df520>,
#   <matplotlib.patches.Wedge at 0x7fdf3b6dfdf0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b6ec700>,
#   <matplotlib.patches.Wedge at 0x7fdf3b6ecfd0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b6fc8e0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b7081f0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b708ac0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b7153d0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b715ca0>,
#   <matplotlib.patches.Wedge at 0x7fdf3b5f1850>,
#   <matplotlib.patches.Wedge at 0x7fdf3b724e50>],
#  [Text(0.07733671984768167, 1.0972780102431658, 'Jan'),
#   Text(-0.29913523861836183, 1.058545279625173, 'Feb'),
#   Text(-0.8781789557505807, 0.6624211060019297, 'Mar'),
#   Text(-1.09078916204387, -0.14205282104777706, 'April'),
#   Text(-0.7391600181912418, -0.8146425397114512, 'May'),
#   Text(-0.13117845514073465, -1.0921502702956634, 'June'),
#   Text(0.7523048464178248, -1.0602063091947027, 'July'),
#   Text(1.018097620948925, -0.4165059834121706, 'Aug'),
#   Text(1.0867528150467645, -0.1702008195865488, 'Sept'),
#   Text(1.0636226824244466, 0.28054730337721134, 'Oct'),
#   Text(0.7948557011726697, 0.7603975370247485, 'Nov'),
#   Text(0.4114734602967833, 1.0201419467267248, 'Dec')],
#  [Text(0.04218366537146273, 0.5985152783144541, '3.3%'),
#   Text(-0.16316467561001555, 0.5773883343410035, '7.7%'),
#   Text(-0.4790067031366803, 0.36132060327377985, '13.0%'),
#   Text(-0.5949759065693837, -0.07748335693515111, '11.7%'),
#   Text(-0.40317819174067726, -0.44435047620624607, '10.7%'),
#   Text(-0.07155188462221888, -0.5957183292521799, '8.9%'),
#   Text(0.46295682856481524, -0.6524346518121246, '14.5%'),
#   Text(0.5553259750630499, -0.22718508186118394, '3.5%'),
#   Text(0.5927742627527806, -0.09283681068357208, '3.9%'),
#   Text(0.5801578267769708, 0.15302580184211526, '9.2%'),
#   Text(0.4335576551850925, 0.4147622929225901, '6.9%'),
#   Text(0.22444006925279086, 0.5564410618509407, '6.6%')])
